# %%
import pandas as pd

# %%
df = pd.read_csv('manysearch-2025-01-14.csv')

# %%
df.sort_values(by='containment')
# Out:
#                                              query_name  containment  \
# 2032  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2002  GCA_024349705.1 Buchnera aphidicola (Ceratovac...     0.109865
# 2001  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2000  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 1999  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# ...                                                 ...          ...
# 4     GCF_024029895.1 Buchnera aphidicola (Periphyll...     0.352679
# 3     GCF_005081445.1 Buchnera aphidicola (Hyadaphis...     0.382661
# 2     GCF_024029895.1 Buchnera aphidicola (Periphyll...     0.435268
# 1     GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.690583
# 0     GCF_013394915.1 Buchnera aphidicola (Aphis gos...     1.000000
#
#       max_containment_ani   match_name
# 2032             0.900175  SRR25131935
# 2002             0.900175   ERR4187870
# 2001             0.900175  ERR10769180
# 2000             0.900175   ERR9843326
# 1999             0.900175  ERR10769202
# ...                   ...          ...
# 4                0.951583  SRR15070562
# 3                0.955287  SRR27437571
# 2                0.961165  SRR11434957
# 1                0.982525  SRR23060064
# 0                1.000000  SRR12060204
#
# [2033 rows x 4 columns]

# %%
run_acc_mapping = pd.read_csv('converted.tsv', sep='\t')

# %%
df2 = df.merge(run_acc_mapping, left_on='match_name', right_on='acc')

# %%
df2
# Out:
#                                              query_name  containment  \
# 0     GCF_013394915.1 Buchnera aphidicola (Aphis gos...     1.000000
# 1     GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.690583
# 2     GCF_024029895.1 Buchnera aphidicola (Periphyll...     0.435268
# 3     GCF_005081445.1 Buchnera aphidicola (Hyadaphis...     0.382661
# 4     GCF_024029895.1 Buchnera aphidicola (Periphyll...     0.352679
# ...                                                 ...          ...
# 2028  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2029  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2030  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2031  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2032  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
#
#       max_containment_ani   match_name        Sample          acc
# 0                1.000000  SRR12060204  SAMN15310392  SRR12060204
# 1                0.982525  SRR23060064  SAMN32686720  SRR23060064
# 2                0.961165  SRR11434957  SAMN13901561  SRR11434957
# 3                0.955287  SRR27437571  SAMN38957063  SRR27437571
# 4                0.951583  SRR15070562  SAMN16357538  SRR15070562
# ...                   ...          ...           ...          ...
# 2028             0.900175  SRR13313226  SAMN16082348  SRR13313226
# 2029             0.900175  SRR13066067  SAMN16577273  SRR13066067
# 2030             0.900175  SRR18191933  SAMN18805052  SRR18191933
# 2031             0.900175  SRR17026832  SAMN23296442  SRR17026832
# 2032             0.900175  SRR25131935  SAMN36291238  SRR25131935
#
# [2033 rows x 6 columns]

# %%
df2.to_csv('manysearch-merged-2024-01-14.csv')

# %%
df2[df2['query_name'].str.contains('Buchnera')]
# Out:
#                                              query_name  containment  \
# 0     GCF_013394915.1 Buchnera aphidicola (Aphis gos...     1.000000
# 1     GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.690583
# 2     GCF_024029895.1 Buchnera aphidicola (Periphyll...     0.435268
# 3     GCF_005081445.1 Buchnera aphidicola (Hyadaphis...     0.382661
# 4     GCF_024029895.1 Buchnera aphidicola (Periphyll...     0.352679
# ...                                                 ...          ...
# 2028  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2029  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2030  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2031  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
# 2032  GCA_011754225.1 Buchnera aphidicola (Periphyll...     0.109865
#
#       max_containment_ani   match_name        Sample          acc
# 0                1.000000  SRR12060204  SAMN15310392  SRR12060204
# 1                0.982525  SRR23060064  SAMN32686720  SRR23060064
# 2                0.961165  SRR11434957  SAMN13901561  SRR11434957
# 3                0.955287  SRR27437571  SAMN38957063  SRR27437571
# 4                0.951583  SRR15070562  SAMN16357538  SRR15070562
# ...                   ...          ...           ...          ...
# 2028             0.900175  SRR13313226  SAMN16082348  SRR13313226
# 2029             0.900175  SRR13066067  SAMN16577273  SRR13066067
# 2030             0.900175  SRR18191933  SAMN18805052  SRR18191933
# 2031             0.900175  SRR17026832  SAMN23296442  SRR17026832
# 2032             0.900175  SRR25131935  SAMN36291238  SRR25131935
#
# [2022 rows x 6 columns]

# %%
df2[df2['query_name'].str.contains('Sulcia')]
# Out:
#                                              query_name  containment  \
# 20    GCA_000147035.1 Candidatus Sulcia muelleri CAR...     0.295620
# 23    GCF_003215395.1 Candidatus Sulcia muelleri, AS...     0.288462
# 26    GCA_000147035.1 Candidatus Sulcia muelleri CAR...     0.284672
# 628   GCF_003215395.1 Candidatus Sulcia muelleri, AS...     0.157692
# 696   GCA_000147035.1 Candidatus Sulcia muelleri CAR...     0.153285
# 1583  GCA_000147035.1 Candidatus Sulcia muelleri CAR...     0.120438
# 1584  GCF_000829155.1 Candidatus Sulcia muelleri PSP...     0.120275
# 1671  GCA_000147035.1 Candidatus Sulcia muelleri CAR...     0.116788
# 1826  GCF_003214655.1 Candidatus Sulcia muelleri, AS...     0.114068
# 1861  GCA_000147035.1 Candidatus Sulcia muelleri CAR...     0.113139
# 1977  GCF_003215265.1 Candidatus Sulcia muelleri, AS...     0.110714
#
#       max_containment_ani   match_name        Sample          acc
# 20               0.943619  SRR19355472  SAMN28422185  SRR19355472
# 23               0.942519   SRR7002830  SAMN08374217   SRR7002830
# 26               0.941925  SRR19355473  SAMN28422185  SRR19355473
# 628              0.915800  SRR25514918  SAMN36834509  SRR25514918
# 696              0.914564    DRR489300  SAMD00599340    DRR489300
# 1583             0.904122    ERR022312   SAMEA930794    ERR022312
# 1584             0.904063    SRR770041  SAMN00113673    SRR770041
# 1671             0.902798  SRR26518997  SAMN12609915  SRR26518997
# 1826             0.901785   SRR7002866  SAMN08928263   SRR7002866
# 1861             0.901434   ERR3623908  SAMEA3712742   ERR3623908
# 1977             0.900505  ERR10791255  SAMEA4832817  ERR10791255
